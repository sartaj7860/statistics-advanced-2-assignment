# %% [markdown]
# Question 1: What is hypothesis testing in statistics?
# ans ) Hypothesis Testing in Statistics 📊
#
# What is Hypothesis Testing? 🤔
#
# Hypothesis testing is a statistical technique used to make inferences about a population parameter based on a sample of data. It involves formulating a hypothesis about the population parameter and then testing it using sample data.
#
# Key Components:
#
# 1. Null Hypothesis (H0): A statement of no effect or no difference.
# 2. Alternative Hypothesis (H1 or Ha): A statement of an effect or difference.
# 3. Test Statistic: A numerical value calculated from the sample data.
# 4. P-value: The probability of obtaining the test statistic (or a more extreme value) assuming H0 is true.
#
# Steps:
#
# 1. Formulate H0 and H1: Clearly define the null and alternative hypotheses.
# 2. Choose a Significance Level (α): Typically set at 0.05.
# 3. Calculate the Test Statistic: Use the sample data to calculate the test statistic.
# 4. Determine the P-value: Calculate the probability of obtaining the test statistic (or a more extreme value) assuming H0 is true.
# 5.
#
# Interpretation:
#
# - Reject H0: Suggests that the observed effect or difference is statistically significant.
# - Fail to Reject H0: Suggests that the observed effect or difference is not statistically significant.
#
# Common Types of Hypothesis Tests:
#
# - T-tests: Compare means between two groups.
# - ANOVA: Compare means among three or more groups.
# - Chi-squared tests: Test for independence between categorical variables.
#
# Why Hypothesis Testing is Important:
#
# - Informed Decision-Making: Hypothesis testing provides a framework for making informed decisions based on data.
# - Scientific Research: Hypothesis testing is a crucial component of scientific research, allowing researchers to test hypotheses and draw conclusions.
#
# Final Answer: Hypothesis testing is a statistical technique used to make inferences about a population parameter based on a sample of data, involving formulating a hypothesis, calculating a test statistic, and determining the P-value to make a decision. 📊
#
# question 2: What is null hypothesis , and how does it differ from alternative hypothesis?
# ans) Null Hypothesis (H0) vs Alternative Hypothesis (H1 or Ha) 📊
#
# Null Hypothesis (H0):
#
# - A statement of no effect or no difference.
# - A statement of equality (e.g., μ = 0, p = 0.5).
# - The hypothesis that is tested for possible rejection.
# - Often denoted as H0.
#
# Alternative Hypothesis (H1 or Ha):
#
# - A statement of an effect or difference.
# - A statement of inequality (e.g., μ ≠ 0, p ≠ 0.5).
# - The hypothesis that is accepted if H0 is rejected.
# - Often denoted as H1 or Ha.
#
# Key Differences:
#
# 1. Statement: H0 states no effect or difference, while H1 states an effect or difference.
# 2. Direction: H0 is often a statement of equality, while H1 is a statement of inequality.
# 3. Purpose: H0 is tested for possible rejection, while H1 is accepted if H0 is rejected.
#
# Examples:
#
# - Research Question: Does a new medicine lower blood pressure?
#     - H0: μ = 0 (The medicine has no effect on blood pressure.)
#     -
# - Research Question: Is there a difference in average height between men and women?
#     - H0: μ1 = μ2 (There is no difference in average height between men and women.)
#     - H1: μ1 ≠ μ2 (There is a difference in average height between men and women.)
#
# Why Null Hypothesis is Used:
#
# 1. Statistical Testing: H0 provides a basis for statistical testing and calculation of probabilities.
# 2. Objectivity: H0 helps to maintain objectivity by assuming no effect or difference unless evidence suggests otherwise.
#
# Common Types of Alternative Hypotheses:
#
# 1. Two-tailed: H1: μ ≠ 0 (Tests for both positive and negative effects)
# 2.
# 3. One-tailed (Right-tailed): H1: μ > 0 (Tests for a positive effect)
#
# In Conclusion: The null hypothesis and alternative hypothesis are two complementary statements that form the basis of statistical hypothesis testing. Understanding the difference between them is crucial for interpreting the results of statistical tests. 📊
#
#  Question 3: Explain the significance level in hypothesis testing and its role in deciding the outcome of a tes?
#  ans ) Significance Level (α) in Hypothesis Testing 📊
#
# What is Significance Level?
#
# - The significance level, denoted by α (alpha), is the maximum probability of rejecting the null hypothesis (H0) when it is actually true.
# - It is the threshold beyond which the results are considered statistically significant.
# - Typically set at 0.05, but can be adjusted depending on the context (e.g., 0.01, 0.1).
#
# Role of Significance Level:
#
# 1. Decision Criterion: α determines the critical region of the test statistic, which in turn determines whether to reject or fail to reject H0.
# 2. Type I Error Control: α controls the probability of Type I error (rejecting H0 when it is true).
# 3. Statistical Significance: α helps determine whether the observed effect or difference is statistically significant.
#
# How Significance Level Affects the Outcome:
#
#  Failing to Reject H0: If the P-value ≥ α, fail to reject H0, indicating no statistical significance.
#
# Choosing the Significance Level:
#
# 1. Context-Dependent: α depends on the research context, such as the field of study, sample size, and consequences of errors.
# 2. Trade-Off: Lower α (e.g., 0.01) reduces Type I error but increases Type II error (failing to reject H0 when it is false).
# 3. Conventional Values: α = 0.05 is commonly used, but other values (e.g., 0.01, 0.1) may be more suitable depending on the situation.
#
# Interpretation and Implications:
#
# 1. Statistical Significance: α helps determine whether the results are statistically significant, but not necessarily practically significant.
# 2. P-Value: The P-value provides more information than just a simple reject/fail-to-reject decision.
# 3. Research Implications: The choice of α affects the conclusions drawn from the research and the potential for Type I and Type II errors.
#
# Common α Values:
#
# 1. α = 0.05: Commonly used in many fields, indicating moderate confidence.
# 2. α = 0.01: Used when high confidence is required, such as in medical research.
# 3. α = 0.1: Used in exploratory studies or when Type II error is a concern.
#
# In Conclusion: The significance level (α) plays a crucial role in hypothesis testing, determining the outcome of a test and controlling Type I error. Understanding α is essential for interpreting statistical results and making informed decisions. 📊
#
# Question 4: What are type l and type ll error? Give examples of each.
# ans) Type I and Type II Errors 📊
#
# Type I Error (α-error):
#
# - Definition: Rejecting the null hypothesis (H0) when it is actually true.
# - Probability: Denoted by α (alpha).
# - Example:
#     - H0: A person is innocent.
#     - H1: A person is guilty.
#     - Type I Error: Convicting an innocent person (rejecting H0 when it is true).
#
# Type II Error (β-error):
#
# - Definition: Failing to reject the null hypothesis (H0) when it is actually false.
# - Probability: Denoted by β (beta).
# - Example:
#     - H0: A person is innocent.
#     - H1: A person is guilty.
#     - Type II Error: Acquitting a guilty person (failing to reject H0 when it is false).
#
# Key Differences:
#
# 1. Direction: Type I error involves rejecting a true H0, while Type II error involves failing to reject a false H0.
# 2. Consequence: Type I error can lead to false positives, while Type II error can lead to false negatives.
#
# More Examples:
#
# - Medical Testing:
#     - Type I Error: Diagnosing a healthy person with a disease (false positive).
#     - Type II Error: Failing to diagnose a person with a disease (false negative).
# - Quality Control:
#     - Type I Error: Rejecting a good product (false positive).
#     - Type II Error: Accepting a defective product (false negative).
#
# Relationship between Type I and Type II Errors:
#
# 1. Trade-Off: Decreasing α (Type I error) can increase β (Type II error), and vice versa.
# 2. Sample Size: Increasing the sample size can reduce both Type I and Type II errors.
#
# Consequences:
#
# 1. Type I Error: Can lead to unnecessary actions, wasted resources, or harm to individuals.
# 2. Type II Error: Can lead to missed opportunities, delayed treatment, or harm to individuals.
#
# In Conclusion: Understanding Type I and Type II errors is crucial in hypothesis testing, as it helps researchers and decision-makers balance the risks of false positives and false negatives. 📊
#
# Question 5: What is the difference between a Z - test and a T - test? Explain when to use each ?
# ans ) Z-test vs T-test 📊
#
# Z-test:
#
# - Definition: A statistical test used to determine whether a sample mean is significantly different from a known population mean, when the population standard deviation is known.
# - Assumptions:
#     - Normality of data or large sample size.
#     - Known population standard deviation (σ).
# - Formula: Z = (x̄ - μ) / (σ / √n)
# - Use Cases:
#     - Comparing a sample mean to a known population mean.
#     - Large sample sizes (n ≥ 30).
#
# T-test:
#
# - Definition: A statistical test used to determine whether a sample mean is significantly different from a known population mean, when the population standard deviation is unknown.
# - Assumptions:
#     - Normality of data or approximately normal.
#     - Unknown population standard deviation (σ).
# - Formula: t = (x̄ - μ) / (s / √n)
# - Use Cases:
#     - Comparing a sample mean to a known population mean.
#     -
#     - Paired samples (e.g., before-and-after observations).
#
# Key Differences:
#
# 1. Population Standard Deviation: Z-test requires known σ, while T-test uses sample standard deviation (s) as an estimate.
# 2. Sample Size: Z-test is suitable for large sample sizes, while T-test is suitable for small sample sizes.
# 3. Distribution: Z-test uses standard normal distribution, while T-test uses t-distribution.
#
# When to Use Each:
#
# 1. Z-test:
#     - When population standard deviation is known.
#     - Large sample sizes (n ≥ 30).
#     - Comparing a sample mean to a known population mean.
# 2. T-test:
#     - When population standard deviation is unknown.
#     -
#     - Paired samples or matched designs.
#
# Types of T-tests:
#
# 1. One-sample T-test: Compare a sample mean to a known population mean.
# 2. Independent Samples T-test: Compare means between two independent groups.
# 3. Paired Samples T-test: Compare means between paired observations (e.g., before-and-after).
#
# In Conclusion: Choosing between Z-test and T-test depends on the research question, sample size, and knowledge of population standard deviation. Understanding the differences between these tests ensures accurate and reliable statistical inferences. 📊

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10      # number of trials
p = 0.5     # probability of success
size = 1000 # number of experiments

# Generate binomial distribution data
data = np.random.binomial(n=n, p=p, size=size)

# Display first few values
print("First 20 generated values:", data[:20])

# Plot histogram
plt.hist(data, bins=range(n+2), edgecolor='black', align='left', alpha=0.7)
plt.title(f"Binomial Distribution (n={n}, p={p})")
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# First 20 generated values: [6 5 5 5 3 7 6 4 7 5 7 7 4 5 3 6 4 2 6 5]

# %%
import numpy as np
from scipy import stats

# Sample data
sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
               50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
               50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
               50.3, 50.4, 50.0, 49.7, 50.5, 49.9]

# Known population parameters
mu_0 = 50          # Hypothesized population mean
sigma = 0.5        # Assume population standard deviation is known

# Sample statistics
n = len(sample_data)
sample_mean = np.mean(sample_data)

# Z-statistic calculation
z_stat = (sample_mean - mu_0) / (sigma / np.sqrt(n))

# Two-tailed p-value
p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))

# Output results
print(f"Sample Size (n): {n}")
print(f"Sample Mean: {sample_mean:.4f}")
print(f"Z-Statistic: {z_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# Decision at alpha = 0.05
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Evidence suggests the mean is different from 50.")
else:
    print("Fail to reject the null hypothesis: No significant evidence the mean differs from 50.")
# Out:
# Sample Size (n): 36
# Sample Mean: 50.0889
# Z-Statistic: 1.0667
# P-Value: 0.2861
# Fail to reject the null hypothesis: No significant evidence the mean differs from 50.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Step 1: Simulate data
np.random.seed(42)  # For reproducibility
mean_true = 100     # True mean
std_dev_true = 15   # True standard deviation
n = 200             # Sample size

data = np.random.normal(loc=mean_true, scale=std_dev_true, size=n)

# Step 2: Calculate sample statistics
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # sample standard deviation

# Step 3: Calculate 95% confidence interval
alpha = 0.05
t_crit = stats.t.ppf(1 - alpha/2, df=n-1)  # critical t-value
margin_error = t_crit * (sample_std / np.sqrt(n))
ci_lower = sample_mean - margin_error
ci_upper = sample_mean + margin_error

print(f"Sample Mean: {sample_mean:.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")

# Step 4: Plot the simulated data
plt.figure(figsize=(8,5))
plt.hist(data, bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(sample_mean, color='red', linestyle='--', label='Sample Mean')
plt.axvline(ci_lower, color='green', linestyle='--', label='95% CI Lower')
plt.axvline(ci_upper, color='green', linestyle='--', label='95% CI Upper')
plt.title("Simulated Normal Distribution with 95% CI")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# Sample Mean: 99.39
# 95% Confidence Interval: (97.44, 101.34)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to calculate Z-scores and plot histogram
def zscore_analysis(data):
    # Calculate mean and standard deviation
    mean = np.mean(data)
    std_dev = np.std(data, ddof=1)  # sample standard deviation

    # Calculate Z-scores
    z_scores = (data - mean) / std_dev

    # Print summary
    print(f"Mean of original data: {mean:.2f}")
    print(f"Standard deviation of original data: {std_dev:.2f}")
    print("First 10 Z-scores:", np.round(z_scores[:10], 2))

    # Plot histogram of Z-scores
    plt.hist(z_scores, bins=20, color='lightcoral', edgecolor='black', alpha=0.7)
    plt.title("Histogram of Standardized Data (Z-scores)")
    plt.xlabel("Z-score")
    plt.ylabel("Frequency")
    plt.axvline(0, color='blue', linestyle='--', label='Mean (Z=0)')
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

    return z_scores

# Example dataset
np.random.seed(42)
data = np.random.normal(loc=100, scale=15, size=200)

# Run the analysis
z_scores = zscore_analysis(data)
# Out:
# Mean of original data: 99.39
# Standard deviation of original data: 13.97
# First 10 Z-scores: [ 0.58 -0.1   0.74  1.68 -0.21 -0.21  1.74  0.87 -0.46  0.63]
